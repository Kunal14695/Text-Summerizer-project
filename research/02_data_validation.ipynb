# %%
import os

# %%
# %pwd
# Out:
# 'D:\\Text-Summerizer-project'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'D:\\'

# %%
import os
os.chdir(r"D:\Text-Summerizer-project")

print(os.getcwd())
# Out:
# D:\Text-Summerizer-project

# %%
from pathlib import Path

print(Path("config/config.yaml").exists())
print(Path("params.yaml").exists())
# Out:
# True
# True

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataValidationConfig:
    root_dir: Path
    STATUS_FILE: str
    ALL_REQUIRED_FILES: list

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        
        create_directories([self.config.artifacts_root])
        
    def get_data_validation_config(self) -> DataValidationConfig:
        config = self.config.data_validation
        
        create_directories([config.root_dir])
        
        data_validation_config= DataValidationConfig(
            root_dir=config.root_dir,
            STATUS_FILE=config.STATUS_FILE,
            ALL_REQUIRED_FILES=config.ALL_REQUIRED_FILES,
        )
        
        return data_validation_config

# %%
import os 
from textSummarizer.logging import logger

# %%
class DataValiadtion:
    def __init__(self, config: DataValidationConfig):
        self.config = config
        
    def validate_all_files_exist(self)-> bool:
        try:
            validation_status = None
            
            all_files = os.listdir(os.path.join("artifacts","data_ingestion","samsum_dataset"))
            
            for file in all_files:
                if file not in self.config.ALL_REQUIRED_FILES:
                    validation_status = False
                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"Validation status: {validation_status}")
                else:
                    validation_status = True
                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"Validation status: {validation_status}")
            
            return validation_status
        
        except Exception as e:
            raise e

# %%
try:
    config = ConfigurationManager()
    data_validation_config = config.get_data_validation_config()
    data_validation = DataValiadtion(config=data_validation_config)
    data_validation.validate_all_files_exist()
except Exception as e:
    raise e
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 7, in __init__
#     self.config = read_yaml(config_filepath)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 872, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 18, in read_yaml
#     logger.info(
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 7, in __init__
#     self.config = read_yaml(config_filepath)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 872, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 18, in read_yaml
#     logger.info(
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 8, in __init__
#     self.params = read_yaml(params_filepath)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 872, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 18, in read_yaml
#     logger.info(
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 8, in __init__
#     self.params = read_yaml(params_filepath)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 872, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 18, in read_yaml
#     logger.info(
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 10, in __init__
#     create_directories([self.config.artifacts_root])
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 37, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 10, in __init__
#     create_directories([self.config.artifacts_root])
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 37, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 3, in <module>
#     data_validation_config = config.get_data_validation_config()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 15, in get_data_validation_config
#     create_directories([config.root_dir])
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 37, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts/data_validation'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 440, in format
#     return self._format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 436, in _format
#     return self._fmt % values
# KeyError: 'modules'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 943, in format
#     return fmt.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 681, in format
#     s = self.formatMessage(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 650, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py", line 442, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'modules'
# Call stack:
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\traitlets\config\application.py", line 1082, in launch_instance
#     app.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\mahen\AppData\Local\Programs\Python\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3887758618.py", line 3, in <module>
#     data_validation_config = config.get_data_validation_config()
#   File "C:\Users\mahen\AppData\Local\Temp\ipykernel_8168\3227228069.py", line 15, in get_data_validation_config
#     create_directories([config.root_dir])
#   File "d:\Text-Summerizer-project\textS\lib\site-packages\ensure\main.py", line 835, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\text-summerizer-project\src\textSummarizer\utils\common.py", line 37, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts/data_validation'
# Arguments: ()
